# %% [markdown]
# ## Tweets
#
# A tweet consists of many data fields. [Here is an example](https://gist.github.com/arapat/03d02c9b327e6ff3f6c3c5c602eeaf8b). You can learn all about them in the Twitter API doc. We are going to briefly introduce only the data fields that will be used in this homework.
#
# * `created_at`: Posted time of this tweet (time zone is included)
# * `id_str`: Tweet ID - we recommend using `id_str` over using `id` as Tweet IDs, becauase `id` is an integer and may bring some overflow problems.
# * `text`: Tweet content
# * `user`: A JSON object for information about the author of the tweet
#     * `id_str`: User ID
#     * `name`: User name (may contain spaces)
#     * `screen_name`: User screen name (no spaces)
# * `retweeted_status`: A JSON object for information about the retweeted tweet (i.e. this tweet is not original but retweeteed some other tweet)
#     * All data fields of a tweet except `retweeted_status`
# * `entities`: A JSON object for all entities in this tweet
#     * `hashtags`: An array for all the hashtags that are mentioned in this tweet
#     * `urls`: An array for all the URLs that are mentioned in this tweet
#
#
# ## Data source
#
# All tweets are collected using the [Twitter Streaming API](https://dev.twitter.com/streaming/overview).
#
#
# ## Users partition
#
# Besides the original tweets, we will provide you with a Pickle file, which contains a partition over 452,743 Twitter users. It contains a Python dictionary `{user_id: partition_id}`. The users are partitioned into 7 groups.

# %% [markdown]
# # Part 0: Load data to a RDD

# %% [markdown]
# The tweets data is stored on AWS S3. We have in total a little over 1 TB of tweets. We provide 10 MB of tweets for your local development. For the testing and grading on the homework server, we will use different data.
#
# ## Testing on the homework server
# In the Playground, we provide three different input sizes to test your program: 1 GB, 10 GB, and 100 GB. To test them, read files list from `../Data/hw2-files-1gb.txt`, `../Data/hw2-files-5gb.txt`, `../Data/hw2-files-20gb.txt`, respectively.
#
# For final submission, make sure to read files list from `../Data/hw2-files-final.txt`. Otherwise your program will receive no points.
#
# ## Local test
#
# For local testing, read files list from `../Data/hw2-files.txt`.
# Now let's see how many lines there are in the input files.
#
# 1. Make RDD from the list of files in `hw2-files.txt`.
# 2. Mark the RDD to be cached (so in next operation data will be loaded in memory)
# 3. call the `print_count` method to print number of lines in all these files
#
# It should print
# ```
# Number of elements: 2193
# ```

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['beta', 'pi', 'dist', 'f']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
# Your code here
with open('./Data/sliced.txt') as f:
    files = [l.strip() for l in f.readlines()]
rdd1 = sc.textFile(','.join(files)).cache()
rdd1.count()
# Out:
# 5448

# %% [markdown]
# # Part 1: Parse JSON strings to JSON objects

# %% [markdown]
# Python has built-in support for JSON.
#
# **UPDATE:** Python built-in json library is too slow. In our experiment, 70% of the total running time is spent on parsing tweets. Therefore we recommend using [ujson](https://pypi.python.org/pypi/ujson) instead of json. It is at least 15x faster than the built-in json library according to our tests.

# %% [markdown]
# ## Broken tweets and irrelevant messages
#
# The data of this assignment may contain broken tweets (invalid JSON strings). So make sure that your code is robust for such cases.
#
# In addition, some lines in the input file might not be tweets, but messages that the Twitter server sent to the developer (such as [limit notices](https://dev.twitter.com/streaming/overview/messages-types#limit_notices)). Your program should also ignore these messages.
#
# *Hint:* [Catch the ValueError](http://stackoverflow.com/questions/11294535/verify-if-a-string-is-json-in-python)
#
#
# (1) Parse raw JSON tweets to obtain valid JSON objects. From all valid tweets, construct a pair RDD of `(user_id, text)`, where `user_id` is the `id_str` data field of the `user` dictionary (read [Tweets](#Tweets) section above), `text` is the `text` data field.

# %%
import ujson

def safe_parse(x):
    try:
        json_object = ujson.loads(x)
    except ValueError, e:
        pass # invalid json
    else:
        return json_object

# your code here

# %%
import re
regex = re.compile('[%s]' % re.escape('!"$%&\'()*+,-./:;<=>?[\\]^_`{|}~\n'))

# %%
# rdd2 = rdd1.filter(lambda x: 'user' in x and 'id_str' in x and 'text' in x).map(safe_parse)\
#         .map(lambda x:  x['text'].encode('utf-8')).cache()
rdd2 = rdd1.filter(lambda x: 'user' in x and 'id_str' in x and 'text' in x).map(safe_parse)\
        .map(lambda x: regex.sub('', x["text"].lower()).encode('utf-8')).cache()
N = rdd2.count()
N
# Out:
# 5448

# %% [markdown]
# # Remove Punctuation Stopwords And Strip

# %%
# ## removing punctuation stopwords and https
# import string
# import nltk
# from nltk.corpus import stopwords
# from nltk.stem import PorterStemmer
# stop_words =set(stopwords.words("english"))
# stop_words|=set(["edu", "com", "also", "still", "anyone", "cc" , "ca", "us", "much", "even", "would", "see", "rt", 'is', 'of'])
# st = PorterStemmer()

# #IMP: Put yout nltk_data folder in /usr/local/share for it to work :)

# def getwords(tweet):
#     return [x for x in tweet if not ( x.startswith('https') or x in stop_words or x is ' ')]
# punc = string.punctuation+"\n"
# table_t = string.maketrans(punc, " "*len(punc))  ##TODO empty word
# tweetNeat = rdd2.map(lambda s: s.translate(table_t).lower())\
#             .map(lambda s: getwords(s.decode('utf-8').split(" "))).filter(lambda x: len(x)>0).map(lambda x: filter(None,x))
# tweetNeat.take(2)
# Out:
# [[u'alwaystrump',
#   u'trump2016',
#   u'trumptrain',
#   u'makeamericagreatagain',
#   u'vote',
#   u'trump',
#   u'co',
#   u'sadz1nys5o'],
#  [u'co', u'dkqaso5wcd', u'trump', u'trump2016']]

# %%
## removing punctuation stopwords and https
import string
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
stop_words =set(stopwords.words("english"))
stop_words|=set(["edu", "com", "also", "still", "anyone", "cc" , "ca", "us", "much", "even", "would", "see", "rt", 'is', 'of'])
st = PorterStemmer()

#IMP: Put yout nltk_data folder in /usr/local/share for it to work :)

def getwords(tweet):
    return [st.stem(x) for x in tweet if not ( x.startswith('htt') or x.startswith('@') or x in stop_words or x is ' ')]

punc = string.punctuation+"\n"
tweetNeat = rdd2.map(lambda s: getwords(s.decode('utf-8').split(" "))).filter(lambda x: len(x)>0).map(lambda x: filter(None,x))
tweetNeat.first()
# Out:
# [u'#alwaystrump',
#  u'trump2016',
#  u'#trumptrain',
#  u'#makeamericagreatagain',
#  u'vote',
#  u'trump']

# %% [markdown]
# # Make Dictionary of Words

# %%
## make dictionary 
vocab = tweetNeat.flatMap(lambda x: x).distinct().collect()
V = len(vocab)
vocab
# Out:
# [u'#bernie2016#bernieorbust',
#  u'#truth',
#  u'#wethepeoplesuperpac4trump',
#  u'inde',
#  u'#f\u2026',
#  u'definit',
#  u'graham',
#  u'dollar',
#  u'#rupe',
#  u'drumpf',
#  u'breakinghispan',
#  u'sanders#berniesand',
#  u'#worldneedsberni',
#  u'dish',
#  u'shot',
#  u'hate',
#  u'ship\u27a1\ufe0fgo',
#  u'gotv',
#  u'tv',
#  u'berner',
#  u'\U0001f602\U0001f602\U0001f602\U0001f602',
#  u'moder',
#  u'#rnrtn#ccot',
#  u'corporat',
#  u'#ak',
#  u'god#berniesand',
#  u'topic',
#  u'umass',
#  u'\U0001f1fa\U0001f1f8\U0001f1fa\U0001f1f8\U0001f1fa\U0001f1f8',
#  u'late',
#  u'terror',
#  u'passion',
#  u'grate',
#  u'sway',
#  u'slogan',
#  u'#secondamend',
#  u'town',
#  u'everi',
#  u'#joedanmedia',
#  u'far',
#  u'now#texasfortrump',
#  u'hopeful\U0001f389regist',
#  u'#overseasvot',
#  u'util',
#  u'print',
#  u'wierdo',
#  u'worst',
#  u'boot',
#  u'candidatesi',
#  u'join',
#  u'#enoughisenough',
#  u'star',
#  u'#rubio',
#  u'#votetrumpsuper\u2026',
#  u'munch',
#  u'topicsbut',
#  u'disgrac',
#  u'fantast',
#  u'impact',
#  u'#tcot',
#  u'complic',
#  u'augustget',
#  u'soiner',
#  u'bruce',
#  u'30yr',
#  u'amend',
#  u'homeown',
#  u'#v\u2026',
#  u'small',
#  u'fl',
#  u'colleagu',
#  u'2016httpstcod1qfp84bnv',
#  u'toppl',
#  u'#alwa\u2026',
#  u'#fbi',
#  u'#teaparti',
#  u'trend',
#  u'playfor',
#  u'relinquish',
#  u'polltrump',
#  u'request',
#  u'#bernies\u2026',
#  u'past',
#  u'go',
#  u'mia',
#  u'#takeourcountryback',
#  u'#stopcoloradocar',
#  u'perfect',
#  u'7th',
#  u'run',
#  u'opportunity\u201d',
#  u'mussolini',
#  u'elegido',
#  u'blue',
#  u'trick',
#  u'hide',
#  u'#femal',
#  u'contributor',
#  u'graveyard\u2049\ufe0f',
#  u'bail',
#  u'#chriswallac',
#  u'#uselect',
#  u'#oklahoma',
#  u'spokesman',
#  u'obamacar',
#  u'#staythecours',
#  u'diggin',
#  u'abt',
#  u'mbqf',
#  u'#hrc',
#  u'ever',
#  u'hummer',
#  u'penalti',
#  u'christian',
#  u'1982',
#  u'picker',
#  u'even',
#  u'lobbyist',
#  u'#weendorseberni',
#  u'#factsmatt',
#  u'#texasvot',
#  u'north#makeamericagreatagain',
#  u'#hillno',
#  u'#berniecs\u2026',
#  u'china',
#  u'#climat',
#  u'nine',
#  u'222224mi',
#  u'magazine\u2013',
#  u'#dontgiveyourvoteto',
#  u'tn',
#  u'515#makeamericagreatagain',
#  u'solid',
#  u'design',
#  u'daughter',
#  u'espa\xf1ol',
#  u'environment',
#  u'33',
#  u'margin',
#  u'270',
#  u'whine',
#  u'bro',
#  u'puppetsw',
#  u'people@realdonaldtrump\xa0go',
#  u'degli',
#  u'action',
#  u'judeo',
#  u'guilti',
#  u'tape',
#  u'honoralbl',
#  u'#trump2016#supertuesday',
#  u'ladyi',
#  u'#madeforhistori',
#  u'elect',
#  u'#justoneberni',
#  u'father',
#  u'#pp',
#  u'#election2016',
#  u'sacrif',
#  u'intent',
#  u'#usa',
#  u'put',
#  u'leav',
#  u'#alwaystrump',
#  u'crba',
#  u'eastwood',
#  u'guy\U0001f444\u261d\ufe0f\U0001f3a9\U0001f418\U0001f513\U0001f466oreilly\u270f\ufe0f\U0001f4d7',
#  u'caucu',
#  u'univ',
#  u'sky',
#  u'sarah',
#  u'countdown',
#  u'eye',
#  u'sake',
#  u'turnout',
#  u'42',
#  u'visit',
#  u'#cnsnew',
#  u'38dontmesswithtx',
#  u'everybodi',
#  u'iq',
#  u'sondaggi#usa',
#  u'#gop2016',
#  u'morn',
#  u'everywher',
#  u'#sup\u2026',
#  u'strike',
#  u'satan',
#  u'prioriti',
#  u'\U0001f448\U0001f682#alwaystrump',
#  u'#513forhrc',
#  u'#jebbush',
#  u'spyingrun',
#  u'#awesom',
#  u'shine',
#  u'#frack',
#  u'door',
#  u'\u201cthere',
#  u'campaigns@realdonaldtrump',
#  u'tax',
#  u'trump#cruzcrew',
#  u'excit',
#  u'impress',
#  u'carri',
#  u'#youredoingitwrong',
#  u'afterparti',
#  u'trump#votetrumptx#secprimary#supertuesday#trump2016#alwaystrump#trumpsess',
#  u'estado',
#  u'\U0001f4a5',
#  u'#trumplandslide#youhavemyvotemrtrump',
#  u'#bestactresshillari',
#  u'effort',
#  u'origin',
#  u'serverif',
#  u'shoot',
#  u'vp',
#  u'word',
#  u'#vote4berni',
#  u'1999',
#  u'jab',
#  u'battl',
#  u'fli',
#  u'#releasethetranscript',
#  u'tinder',
#  u'jordan',
#  u'motiv',
#  u'didnt',
#  u'trustworthi',
#  u'nashvil',
#  u'control',
#  u'#supertuesday#alwaystrump',
#  u'del',
#  u'bureau',
#  u'balboaberni',
#  u'clearance@oldrancocasand',
#  u'#1a\u261b',
#  u'predict',
#  u'#davidduk',
#  u'share',
#  u'#dnc',
#  u'texasher',
#  u'high',
#  u'#racecard#dem',
#  u'strengthen',
#  u'#getupstandup',
#  u'libertarian',
#  u'mindlesszombies23',
#  u'flint',
#  u'attract',
#  u'encuesta',
#  u'#marcomentum#alwaystrumphttpstcobiggoo7vzz',
#  u'filter',
#  u'end',
#  u'steve',
#  u'polic',
#  u'#clinron',
#  u'parenthood',
#  u'monday\U0001f389donald',
#  u'environ',
#  u'owner',
#  u'europ',
#  u'1',
#  u'#hitlerswa',
#  u'#libya',
#  u'caus',
#  u'sunni',
#  u'front',
#  u'answer',
#  u'mediait',
#  u'155',
#  u'beach',
#  u'#supertuesday',
#  u'pink',
#  u'tide',
#  u'stood',
#  u'prolif',
#  u'farm',
#  u'stop',
#  u'#support',
#  u'ego',
#  u'university\u2013',
#  u'ronald',
#  u'#foxdead',
#  u'undocu',
#  u'particip',
#  u'#fl4trump',
#  u'yrsopposit',
#  u'klan',
#  u'#alwaystrump#trump2016\U0001f449',
#  u'data',
#  u'#copol',
#  u'#mnleg',
#  u'#trump2016#makeamericagreatagain',
#  u'\u2764\ufe0f\u2764\ufe0f\U0001f525\U0001f525',
#  u'attempt',
#  u'ss',
#  u're\u2026',
#  u'june',
#  u'fine',
#  u'#makeamericagreatagain#alwaystrump',
#  u'rather',
#  u'giorno',
#  u'funniest',
#  u'vekgdynujdox',
#  u'#mpl',
#  u'sc',
#  u'fan',
#  u'podemo',
#  u'dream',
#  u'ideolog',
#  u'#gopprimari',
#  u'feed',
#  u'unravel',
#  u'#trumpnowhttpstco5rl1vwgqam',
#  u'charm',
#  u'alon',
#  u'telecom',
#  u'some1',
#  u'#hilla\u2026',
#  u'approv',
#  u'gasolin',
#  u'elit',
#  u'control#alwaystrump',
#  u'runner',
#  u'#alprimari',
#  u'grayson',
#  u'#b\u2026',
#  u'que',
#  u'#shewilllos',
#  u'ethic',
#  u'write',
#  u'86',
#  u'complac',
#  u'group',
#  u'critiqu',
#  u'#fee\u2026',
#  u'11carson',
#  u'border',
#  u'shillari',
#  u'justic',
#  u'better',
#  u'feel',
#  u'#whatishillaryhid',
#  u'contigo',
#  u'foundat',
#  u'van',
#  u'stephen',
#  u'collus',
#  u'might',
#  u'fool',
#  u'tri',
#  u'return',
#  u'appoint',
#  u'h\u2026',
#  u'ya',
#  u'qualiti',
#  u'218221',
#  u'#davidbowi',
#  u'break',
#  u'interview',
#  u'promis',
#  u'food',
#  u'24',
#  u'payback',
#  u'sht',
#  u'investor',
#  u'josh',
#  u'wont',
#  u'reich',
#  u'#wpr',
#  u'gilli',
#  u'#cruzzod',
#  u'panic',
#  u'oliv',
#  u'gilley',
#  u'#trumpwin',
#  u'#berniec\u2026',
#  u'wage',
#  u'lyi\u2026',
#  u'done',
#  u'oblig',
#  u'litmu',
#  u'#tedcruz\u2019',
#  u'#vaforberni',
#  u'estar',
#  u'brag',
#  u'navi',
#  u'#feelthelov',
#  u'#boycottfoxnew',
#  u'fals',
#  u'#nra',
#  u'#vote4trump',
#  u'demor',
#  u'member',
#  u'clinton@realdonaldtrump',
#  u'\u203c\ufe0f\U0001f1fa\U0001f1f8\u2764\ufe0f\U0001f499',
#  u'#stopfed',
#  u'compet',
#  u'#trump2016httpstcof4y\u2026',
#  u'chevi',
#  u'senat',
#  u'canada',
#  u'huh',
#  u'now\U0001f389#donaldtrump',
#  u'profit',
#  u'gtgt',
#  u'#rubio#trump2016#alwaystrumpsecprimaryhttpstcofztkpstri',
#  u'identifi',
#  u'\u2600\ufe0f#trust',
#  u'blm',
#  u'may',
#  u'thoma',
#  u'lawsuit',
#  u'rare',
#  u'#makeyourb',
#  u'bless',
#  u'strategist',
#  u'ass',
#  u'#alangrayson',
#  u'hahahaberni',
#  u'wisconsin',
#  u'chitchat',
#  u'spot',
#  u'pleas',
#  u'20',
#  u'disrespect',
#  u'#trump2016httpstcosutcdoip3c',
#  u'for#berniesanders#worldneedsberni',
#  u'california',
#  u'whop',
#  u'ask',
#  u'est#votetrumpva#secprimary#trump2016#trumptrain\U0001f682\U0001f1fa\U0001f1f8https\u2026',
#  u'hiding#feelthebern',
#  u'6pack',
#  u'increas',
#  u'union',
#  u'thrown',
#  u'director',
#  u'perform',
#  u'proudli',
#  u'miss',
#  u'lone',
#  u'223#cruz',
#  u'\u2764\ufe0f\U0001f1fa\U0001f1f8\u2764\ufe0f',
#  u'punk',
#  u'count',
#  u'\U0001f447\U0001f447\U0001f447\U0001f447\U0001f447\U0001f447',
#  u'youll',
#  u'place',
#  u'nastyguy',
#  u'#donalddrumpf',
#  u'valdosta',
#  u'#hilary2016',
#  u'onto',
#  u'#jesusontri',
#  u'suppos',
#  u'oper',
#  u'info',
#  u'#protest',
#  u'#gold',
#  u'friends\U0001f1fa\U0001f1f8\U0001f1fa\U0001f1f8\U0001f1fa\U0001f1f8',
#  u'trembl',
#  u'spoken',
#  u'sock',
#  u'prevail',
#  u'#allamericanlivesmattertoo',
#  u'cave\u201dhttpstcot7eajgojfq',
#  u'restrict',
#  u'will',
#  u'#msm',
#  u'357',
#  u'hang',
#  u'vote',
#  u'open',
#  u'gooo',
#  u'sheep',
#  u'avail',
#  u'go\U0001f51d',
#  u'#nottrump2016',
#  u'#realchang',
#  u'lap',
#  u'eu',
#  u'#sexist',
#  u'oppos',
#  u'#lockland',
#  u'carson',
#  u'#wenotm',
#  u'#alwaystrumpread',
#  u'99',
#  u'puppet',
#  u'brainwash',
#  u'draft',
#  u'#rednationris',
#  u'woe',
#  u'ovat',
#  u'yet#secprimari',
#  u'audit',
#  u'ballot',
#  u'postcard',
#  u'\u201cwe\u2019v',
#  u'#snowzilla',
#  u'dal',
#  u'#trumpornothin',
#  u'loooooooov',
#  u'albert',
#  u'candidatesim',
#  u'60',
#  u'sort',
#  u'broadcast',
#  u'illeg',
#  u'560',
#  u'endor\u2026',
#  u'#feelthebe\u2026',
#  u'#lodi',
#  u'domin',
#  u'hair',
#  u'crawl',
#  u'#nomin',
#  u'11',
#  u'jump',
#  u'15',
#  u'#bernie\u2026',
#  u'co',
#  u'2015',
#  u'provid',
#  u'5#alwaystrump',
#  u'millenni',
#  u'afford',
#  u'today\U0001f389donald',
#  u'word#alwaystrump',
#  u'stalk',
#  u'#bernievshillari',
#  u'posit',
#  u'video',
#  u'india',
#  u'#cru\u2026',
#  u'night#makeyoutubegreatagain',
#  u'brilliant',
#  u'#cronycapit',
#  u'pre',
#  u'benghazi',
#  u'gaga',
#  u'#nothillari',
#  u'#cruz',
#  u'viewer',
#  u'well',
#  u'#supertuesday#trump2016',
#  u'upset',
#  u'alleg',
#  u'fail',
#  u'wasnt',
#  u'#tytliv',
#  u'comedian',
#  u'#alwaystrumpbenghazi',
#  u'texass',
#  u'sheet',
#  u'infring',
#  u'#mapoli',
#  u'gomert',
#  u'saw',
#  u'bait',
#  u'sell',
#  u'detent',
#  u'sabotag',
#  u'date',
#  u'tough',
#  u'#americatogeth',
#  u'#pgh',
#  u'\u2018craziest',
#  u'chatter',
#  u'note',
#  u'jewish',
#  u'lip',
#  u'prefer',
#  u'libyahttpstcoaxgwvqklhx',
#  u'#trumparmi',
#  u'combin',
#  u'amp#obama',
#  u'#rino',
#  u'#patriot',
#  u'ideologyvot',
#  u'tonight',
#  u'led',
#  u'beneficiari',
#  u'test',
#  u'#trumptra\u2026',
#  u'#topprog',
#  u'senil',
#  u'reach',
#  u'comm',
#  u'marin',
#  u'\U0001f1fa\U0001f1f8#alwaystrump',
#  u'attentionh',
#  u'mouth',
#  u'#cruzcew',
#  u'rollout',
#  u'cosplay',
#  u'#hillarysocorrupt',
#  u'#thebigshort',
#  u'2011',
#  u'#veteran',
#  u'#howardstern',
#  u'todo',
#  u'pathet',
#  u'#alwaystrump#onlytrumpdont',
#  u'oath',
#  u'cover',
#  u'#8bittrump',
#  u'proamnestyopen',
#  u'#potu',
#  u'tech',
#  u'sheikh',
#  u'shitlib',
#  u'brew',
#  u'link',
#  u'#actor',
#  u'steadi',
#  u'#texas4\u2026',
#  u'#pjn\u2026',
#  u'ungar',
#  u'#standwithberni',
#  u'#live',
#  u'bomb',
#  u'#clivenbundi',
#  u'crap',
#  u'd\u2026',
#  u'abl',
#  u'who#imwithh',
#  u'jtrump',
#  u'demean',
#  u'counti',
#  u'richfolk',
#  u'214218',
#  u'radio',
#  u'stuf',
#  u'yaaaa',
#  u'radic',
#  u'mexican',
#  u'#trump\u261aw',
#  u'texa',
#  u'becausegross',
#  u'involv',
#  u'crush',
#  u'#newswir',
#  u'#theweek',
#  u'music',
#  u'#jdnet',
#  u'223',
#  u'director#makeamericagreatagain',
#  u'#usmarin',
#  u'\U0001f389',
#  u'mighti',
#  u'black',
#  u'999',
#  u'kennam',
#  u'sierra',
#  u'shameony',
#  u'footnot',
#  u'\U0001f1fa\U0001f1f8senat',
#  u'stab',
#  u'200000',
#  u'serv',
#  u'#releasethetranscriptswhat',
#  u'hit',
#  u'nutjob',
#  u'#tulsa',
#  u'beat',
#  u'#foxnewsrachel',
#  u'#hillaryclinton',
#  u'watch',
#  u'decreas',
#  u'#nyt',
#  u'pocket',
#  u'#kentucki',
#  u'\U0001f525',
#  u'quick',
#  u'michael',
#  u'report',
#  u'ben',
#  u'youtub',
#  u'#teammarco',
#  u'receiv',
#  u'\U0001f4a5\U0001f4a3\U0001f4a5\U0001f4a3',
#  u'#fucktrump',
#  u'#votetrumpoh',
#  u'politician',
#  u'feudalist',
#  u'19',
#  u'roger',
#  u'tale',
#  u'\U0001f335',
#  u'hype',
#  u'privileg',
#  u'#2chronicles714',
#  u'steal',
#  u'inaugur',
#  u'respond',
#  u'feast',
#  u'stump',
#  u'grain',
#  u'volunt',
#  u'oversea',
#  u'#justiceforflint',
#  u'#makeamericagreatagain',
#  u'mind',
#  u'conscienc',
#  u'\U0001f30e\U0001f30d\U0001f30f\u2764\ufe0f\U0001f525',
#  u'deadlin',
#  u'corrupt',
#  u'hero',
#  u'simpl',
#  u'#usnavi',
#  u'#msnbc',
#  u'mckay',
#  u'is#berniesanders#worldneedsberni',
#  u'moron',
#  u'estab',
#  u'forceabl',
#  u'#revolut',
#  u'ralph',
#  u'#scdemprimari',
#  u'everyvot',
#  u'case',
#  u'#minor',
#  u'staffer',
#  u'mislead',
#  u'atroc',
#  u'2016httpstcoawv\u2026',
#  u'earli',
#  u'pfft',
#  u'medicar',
#  u'trumpeffect',
#  u'blow',
#  u'omg',
#  u'#forreal',
#  u'p\u2026',
#  u'#votehillari',
#  u'wo',
#  u'\U0001f64c\U0001f3fb\U0001f64c\U0001f3fb',
#  u'injo',
#  u'court',
#  u'viral\u2026',
#  u'flow',
#  u'cheap',
#  u'#hillaryclintoncnn',
#  u'blame',
#  u'#startyourfuturenow',
#  u'press',
#  u'brokendo',
#  u'wth',
#  u'clueless',
#  u'#skimmlif',
#  u'dishonor',
#  u'come',
#  u'#onlyoneberni',
#  u'water',
#  u'coutri',
#  u'#vaprimaryrcp',
#  u'career',
#  u'to\u2026',
#  u'#trump2016\U0001f1fa\U0001f1f8',
#  u'#vet',
#  u'#cbsnew',
#  u'630',
#  u'polici',
#  u'fnc',
#  u'#berniewho',
#  u'winnertakeall\u2019',
#  u'let',
#  u'planet',
#  u'whole',
#  u'comment',
#  u'episod',
#  u'senza',
#  u'#vermont',
#  u'estateonli',
#  u'straight\u25bahttpstco2wyeablmgi\u25c4',
#  u'soy',
#  u'#glennbeck',
#  u'solv',
#  u'anti',
#  u'#gay',
#  u'cancel',
#  u'outta',
#  u'deputati',
#  u'corp',
#  u'embrac',
#  u'damerica',
#  u'#cuban',
#  u'nychttpstcoxibfviodaa#wethepeopl',
#  u'yay',
#  u'supermart',
#  u'#clintonshttpstcoxdkhgbvk5i',
#  u'#kkk',
#  u'#votetrumpsu\u2026',
#  u'\u2764\ufe0f\u2764\ufe0f',
#  u'29th#gop',
#  u'statesfeb',
#  u'ran',
#  u'yasher',
#  u'#pjnet',
#  u'boughttrump',
#  u'singlepli',
#  u'freak',
#  u'tyrann',
#  u'tank',
#  u'#usnotm',
#  u'goals\u2014but',
#  u'irl',
#  u'yessssss',
#  u'fire',
#  u'romney',
#  u'#uniteblu',
#  u'pat',
#  u'\U0001f44a\U0001f510',
#  u'deliber',
#  u'#votetrump2016',
#  u'startedvot',
#  u'#pragmatist',
#  u'catch',
#  u'last',
#  u'leighmunsil',
#  u'spin',
#  u'resid',
#  u'#makeamericagreatagain#trump2016httpstconzs31hhnrl',
#  u'sound',
#  u'dash',
#  u'#tedcruz',
#  u'racist#alwaystrump',
#  u'hat',
#  u'harder',
#  u'innuendo',
#  u'employ',
#  u'fwd',
#  u'#bet',
#  u'preserv',
#  u'fun',
#  u'#notmew',
#  u'forg',
#  u'wake',
#  u'#cruzcr\u2026',
#  u'real',
#  u'regul',
#  u'10000',
#  u'florida',
#  u'project',
#  u'almost',
#  u'disavow',
#  u'outspent',
#  u'roar',
#  u'poll#alwaystrump#secprimaryhttpstcowfl8la2srn',
#  u'willi',
#  u'sides#wethepeopl',
#  u'need',
#  u'im',
#  u'track',
#  u'outrag',
#  u'crash',
#  u'insan',
#  u'#unit',
#  u'outspend',
#  u'humili',
#  u'grown',
#  u'irrelev',
#  u'genit',
#  u'#vra',
#  u'your\u2026',
#  u'nazi',
#  u'widen',
#  u'woodland',
#  u'miami',
#  u'2008we',
#  u'2derail',
#  u'read',
#  u'ver',
#  u'speech',
#  u'warmong',
#  u'9',
#  u'conartist',
#  u'#vegan',
#  u'medit',
#  u'revolutionari',
#  u'week',
#  u'mexicanschines',
#  u'#berniesandersfo\u2026',
#  u'512th2elect',
#  u'damn',
#  u'saddam',
#  u'mrtrump',
#  u'tenga',
#  u'\u2018outstanding\u2019',
#  u'upon',
#  u'liar\u2019',
#  u'filthi',
#  u'delight',
#  u'#marcoroboto',
#  u'altern',
#  u'rightsocialismcapitalist',
#  u'fox\u201d',
#  u'#makeamericahateagain',
#  u'paradox',
#  u'#afuturetobelievein',
#  u'#okpimari',
#  u'flybynight',
#  u'thedailybeast',
#  u'#vets4berni',
#  u'blatantli',
#  u'theater',
#  u'8@tedcruz',
#  u'rube',
#  u'pennsylvania',
#  u'#vtpoli',
#  u'crubio',
#  u'willbether',
#  u'oo',
#  u'#okc',
#  u'thought',
#  u'sociopaths\u2026',
#  u'command',
#  u'#demprimari',
#  u'react',
#  u'trump\u2014#dtmag',
#  u'judg',
#  u'\u23f0becaus',
#  u'capuano',
#  u'taxessupport',
#  u'#famili',
#  u'sec',
#  u'loserbut',
#  u'#nyfortrump',
#  u'spptr',
#  u'#tx',
#  u'enjoy',
#  u'stalwart',
#  u'dishonesti',
#  u'activ',
#  u'#trumpforprez',
#  u'gabbard',
#  u'kill',
#  u'touch',
#  u'love',
#  u'cracker',
#  u'speed',
#  u'down',
#  u'taken',
#  u'concentr',
#  u'#politicalrevolution\u2026',
#  u'#trumpteam',
#  u'poll224225',
#  u'exclus',
#  u'cruzlin',
#  u'disagre',
#  u'lifelong',
#  u'recip',
#  u'percent',
#  u'#makeamericagreatagaintax',
#  u'#berniefam',
#  u'barack',
#  u'wall',
#  u'#5thcolumn',
#  u'divis',
#  u'wuzza',
#  u'ok',
#  u'#alwaystru\u2026',
#  u'326',
#  u'silver538\u2019',
#  u'truthful\u2019',
#  u'224226mi',
#  u'clintoid',
#  u'march',
#  u'195m',
#  u'rnc',
#  u'reagan',
#  u'wall\u2026healthcar',
#  u'ladi',
#  u'it#cruzcrew#trusted#tcot#pjnet#ccot#cruz#wakeupamericahttps\u2026',
#  u'nro',
#  u'tmrw',
#  u'shocker',
#  u'machin',
#  u'kasi',
#  u'#georgesoro',
#  u'govt',
#  u'cooki',
#  u'dr',
#  u'gen\u2026',
#  u'color',
#  u'gunown',
#  u'brought',
#  u'#pda',
#  u'approach',
#  u'doj',
#  u'greyson',
#  u'55',
#  u'#anonym',
#  u'seek',
#  u'dishonest',
#  u'websit',
#  u'trakingof',
#  u'servant',
#  ...]

# %% [markdown]
# # Histogram of Words

# %%
## Annotate words
import numpy as np

tweetHist = tweetNeat.map(lambda s: np.array([vocab.index(k) for k in s if k in vocab]))\
          .map(lambda y: np.bincount(y.astype(int), minlength=len(vocab)))
#tweetHist.take(2)
tweetHist.first()
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %% [markdown]
# # Part 2 : Gibbs Sampler for Naive Bayes
# Naive Bayes:\\
# //Prior
# • For each latent class c ∈ {1,...,K}
#     • θ(c) ∼ Dirichlet(α)
# • π ∼ Dirichlet(β) //Likelihood
# • For each document d ∈ {1,...,N}
#     • Document latent class z(d) ∼ discrete(π)
#     • For each word i in document d
#         • w(d) ∼ discrete(θ(z(d))) //Sample a word i

# %%
def sampleFromDiscrete(probs):
    temp = random.random()
    total =0
    for i in range(len(probs)):
        total+=probs[i]
        if(temp<total):
            return i
    return 0

# %% [markdown]
# Z initialised based on similarity measure

# %%
K=15 # NO of classes.
alpha = np.ones(V)*0.1 #hyperparameter
A = [alpha]*K
beta = np.ones(K)
pi = np.random.dirichlet(beta)
pi1=pi
theta = np.random.dirichlet(alpha, K)
no_tweets = N
doc_vec = tweetHist.collect()
docs = set(range(0, N))
z = [0]*N
for i in range(K):
    d = docs.pop()
    z[d] = i
    dist = np.linalg.norm(doc_vec - doc_vec[d], axis=1)
    sorted_dist = np.argsort(dist)[0:N/K]
    for k in sorted_dist:
        docs.discard(k)
        doc_vec[k] = [-np.inf]*len(doc_vec[0])
        z[k] = i

# %% [markdown]
# # Gibbs Sampler (Naive Bayes)

# %%
np.bincount(z) + beta
# Out:
# array([ 367.,  364.,  364.,  364.,  364.,  364.,  364.,  364.,  364.,
#         364.,  364.,  364.,  364.,  364.,  364.])

# %%
print np.shape(beta)
# Out:
# (15,)

# %%
doc_vectors = tweetHist.collect()
for i in range(80):
    print bincount(z)
    pi = np.random.dirichlet(beta + np.bincount(z, minlength=K))
    sum_z = np.zeros((K, V))
    for i in range(no_tweets):
        sum_z[z[i]]+=doc_vectors[i]
    for i in range(K):
        theta[i] = np.random.dirichlet(A[i]+sum_z[i])
    for d in range(no_tweets):
        for i in range(K):
            pi1[i]= np.dot(np.log(theta[i]),doc_vectors[d])
        pi1 = np.exp(pi1-np.max(pi1))
        for i in range(K):
            pi1[i] *= pi[i]
        pi1 = pi1/np.sum(pi1)
        #print pi1
        z[d]=sampleFromDiscrete(pi1)
# Out:
# [213 328 318 340 379 336 421 446 338 397 395 384 405 364 384]
# [196 293 320 348 387 351 395 465 334 402 393 388 410 381 385]
# [184 268 326 357 394 357 394 466 322 399 406 384 409 390 392]
# [193 258 329 354 399 355 393 461 326 397 407 381 415 388 392]
# [195 251 316 353 406 353 397 451 323 413 416 375 416 387 396]
# [185 250 320 348 405 359 394 448 325 421 405 377 414 398 399]
# [182 247 318 358 397 364 392 446 316 424 406 381 425 396 396]
# [179 249 315 347 396 362 390 440 317 432 405 380 423 410 403]
# [181 239 313 354 392 375 389 431 323 430 409 380 427 406 399]
# [182 242 312 343 391 379 388 426 316 438 411 382 430 410 398]
# [196 242 311 333 391 370 387 430 311 444 412 386 437 409 389]
# [187 230 313 329 398 377 384 435 314 449 417 381 433 409 392]
# [187 225 317 332 393 376 384 431 304 462 418 385 421 415 398]
# [194 229 314 347 396 375 384 434 307 442 414 392 416 413 391]
# [197 222 307 348 391 373 385 441 307 441 417 384 425 411 399]
# [191 199 310 348 397 378 381 443 314 443 411 390 430 421 392]
# [183 201 306 337 409 395 384 438 315 448 406 385 427 419 395]
# [193 205 310 331 395 391 381 438 319 441 416 383 426 426 393]
# [193 205 307 331 387 388 389 449 309 444 425 379 426 425 391]
# [191 210 304 335 380 386 384 451 313 440 425 376 438 426 389]
# [199 212 305 329 379 375 389 445 312 454 427 377 433 428 384]
# [197 214 304 332 372 383 383 445 311 444 432 384 433 427 387]
# [198 212 298 327 384 379 381 447 309 450 431 381 432 431 388]
# [214 210 305 316 382 379 382 442 305 454 434 381 428 436 380]
# [231 201 305 300 373 376 381 455 305 451 433 381 433 445 378]
# [247 202 307 290 382 373 384 441 290 455 441 381 433 447 375]
# [257 205 298 296 380 378 384 433 291 451 439 382 433 447 374]
# [245 205 301 297 375 378 381 437 288 460 448 381 423 450 379]
# [255 201 300 285 376 375 385 435 285 470 440 380 429 448 384]
# [250 198 295 292 377 381 383 447 289 458 434 383 430 447 384]
# [246 195 295 293 373 378 382 435 294 466 444 385 427 445 390]
# [256 199 299 299 364 369 381 442 293 454 446 386 432 442 386]
# [254 200 299 297 364 378 381 438 297 454 435 380 432 452 387]
# [256 209 300 299 358 382 379 436 291 448 439 378 434 453 386]
# [252 211 302 291 375 380 377 426 299 449 438 379 433 450 386]
# [260 200 301 296 367 375 376 432 288 445 445 380 439 456 388]
# [258 196 297 288 371 373 372 440 286 450 441 385 438 457 396]
# [280 194 298 284 369 376 378 445 289 433 436 382 435 454 395]
# [275 200 301 285 361 371 371 447 295 438 437 369 441 454 403]
# [272 202 300 278 361 371 375 449 294 447 442 366 443 446 402]
# [269 194 298 284 360 373 376 439 293 446 448 370 446 447 405]
# [265 200 300 289 347 373 376 447 295 433 436 375 450 459 403]
# [266 205 299 288 352 367 375 448 305 437 436 366 444 452 408]
# [271 218 298 279 353 372 373 453 293 445 427 365 443 454 404]
# [273 208 306 278 356 368 372 450 285 449 426 373 452 452 400]
# [279 208 292 286 348 370 373 440 291 442 434 369 447 471 398]
# [272 211 297 283 351 365 373 452 289 437 426 368 451 471 402]
# [265 213 303 284 347 369 369 450 289 449 424 371 454 457 404]
# [276 212 302 282 346 375 372 448 291 441 417 367 450 469 400]
# [276 205 301 288 353 372 370 448 291 440 428 368 452 456 400]
# [278 216 296 282 344 371 373 437 290 449 433 372 456 456 395]
# [275 225 291 281 344 378 369 439 289 446 443 365 453 453 397]
# [285 223 284 282 341 369 373 439 293 455 432 374 444 452 402]
# [285 223 294 278 346 376 373 445 287 448 436 368 442 447 400]
# [296 209 287 274 353 368 371 447 291 434 437 375 453 453 400]
# [298 217 287 270 344 369 375 441 293 444 434 373 449 458 396]
# [293 212 281 281 348 375 374 442 292 452 423 372 453 453 397]
# [301 215 287 271 352 372 370 438 296 438 426 372 454 458 398]
# [305 208 285 270 349 374 371 441 288 445 420 373 449 474 396]
# [306 211 284 271 352 371 369 439 289 447 405 376 445 482 401]
# [302 214 284 267 350 376 374 441 285 444 409 372 445 479 406]
# [292 206 289 280 353 385 370 433 284 433 403 377 454 486 403]
# [305 201 287 275 356 373 369 439 284 438 400 378 457 481 405]
# [300 208 287 269 349 365 370 439 280 448 405 377 453 492 406]
# [303 205 285 270 350 376 372 437 283 448 401 381 450 480 407]
# [295 209 290 269 349 372 367 438 285 448 408 375 460 479 404]
# [301 212 285 267 348 381 365 438 291 437 409 375 452 485 402]
# [308 212 286 268 356 384 368 436 281 444 399 374 458 475 399]
# [301 217 283 268 345 377 367 437 286 449 411 366 455 486 400]
# [304 218 283 270 342 388 368 441 279 448 401 368 458 480 400]
# [298 210 285 266 344 379 371 444 283 455 402 371 461 479 400]
# [299 216 287 264 343 383 368 437 273 448 409 369 458 487 407]
# [301 216 286 267 339 384 369 444 276 453 405 369 455 479 405]
# [295 209 285 267 343 376 371 439 279 461 412 376 450 485 400]
# [306 214 289 267 344 376 371 434 276 454 406 374 451 478 408]
# [300 206 281 272 344 379 371 431 277 463 411 377 453 481 402]
# [298 212 282 268 343 381 371 431 273 453 418 378 450 488 402]
# [304 209 284 267 342 377 371 430 274 451 411 379 453 493 403]
# [297 213 285 273 343 377 373 432 278 455 406 381 446 488 401]
# [289 210 292 272 349 378 374 433 272 439 406 381 460 495 398]

# %%
print z
# Out:
# [0, 12, 2, 2, 3, 4, 13, 5, 6, 6, 7, 6, 8, 9, 3, 5, 10, 8, 11, 11, 10, 8, 0, 12, 5, 4, 11, 9, 13, 9, 5, 13, 2, 5, 12, 6, 6, 5, 11, 8, 14, 11, 13, 5, 3, 10, 5, 14, 4, 6, 9, 8, 9, 5, 14, 6, 10, 9, 13, 5, 0, 12, 5, 0, 5, 5, 6, 0, 5, 14, 2, 7, 11, 5, 8, 13, 3, 9, 10, 3, 10, 5, 13, 3, 7, 0, 5, 9, 13, 7, 14, 10, 6, 12, 12, 9, 3, 5, 0, 8, 5, 2, 2, 11, 6, 5, 11, 7, 11, 5, 13, 2, 11, 5, 7, 14, 1, 1, 2, 10, 13, 3, 5, 0, 5, 8, 11, 10, 0, 12, 13, 4, 2, 9, 3, 5, 14, 1, 8, 5, 8, 2, 0, 14, 2, 3, 9, 5, 2, 6, 8, 5, 0, 6, 3, 0, 8, 14, 5, 10, 5, 0, 5, 3, 1, 11, 5, 8, 2, 3, 3, 4, 9, 14, 3, 14, 0, 0, 10, 4, 11, 5, 14, 8, 5, 13, 6, 5, 7, 11, 5, 13, 12, 6, 14, 5, 13, 14, 2, 7, 10, 9, 11, 11, 0, 2, 8, 14, 5, 5, 0, 14, 2, 6, 5, 9, 11, 13, 14, 2, 8, 5, 8, 6, 14, 6, 3, 0, 13, 9, 13, 14, 7, 9, 6, 13, 6, 14, 13, 4, 14, 9, 9, 11, 5, 3, 2, 12, 14, 0, 9, 14, 5, 14, 1, 5, 5, 2, 10, 11, 0, 5, 2, 5, 5, 9, 5, 11, 3, 4, 2, 9, 2, 5, 4, 5, 14, 0, 6, 0, 5, 10, 2, 3, 2, 7, 9, 11, 6, 11, 6, 3, 8, 4, 12, 7, 6, 6, 9, 5, 9, 10, 5, 6, 2, 9, 10, 11, 12, 3, 10, 14, 5, 11, 5, 0, 7, 2, 2, 5, 14, 7, 7, 5, 14, 12, 5, 5, 8, 10, 7, 2, 5, 5, 13, 5, 4, 14, 9, 7, 5, 0, 9, 14, 10, 3, 9, 5, 4, 12, 14, 5, 8, 14, 8, 12, 12, 11, 14, 0, 0, 0, 5, 5, 10, 10, 0, 11, 5, 0, 9, 5, 13, 9, 6, 2, 2, 6, 7, 9, 6, 11, 6, 8, 9, 2, 14, 6, 3, 5, 6, 6, 12, 11, 10, 12, 2, 14, 5, 3, 11, 0, 5, 0, 12, 5, 0, 13, 5, 3, 0, 14, 9, 0, 10, 0, 0, 10, 8, 3, 14, 7, 5, 6, 13, 8, 9, 9, 0, 2, 13, 13, 11, 7, 10, 4, 5, 11, 5, 0, 12, 3, 0, 9, 6, 0, 9, 2, 5, 5, 5, 5, 8, 12, 14, 14, 13, 2, 9, 0, 5, 13, 12, 0, 9, 2, 0, 6, 5, 3, 3, 7, 9, 13, 13, 14, 2, 14, 13, 12, 6, 12, 7, 9, 7, 8, 6, 13, 13, 0, 6, 10, 2, 2, 5, 4, 14, 2, 8, 0, 5, 8, 11, 5, 0, 5, 2, 2, 5, 14, 9, 0, 10, 0, 9, 7, 2, 12, 8, 11, 0, 8, 2, 8, 2, 0, 12, 2, 0, 11, 7, 9, 9, 3, 6, 2, 10, 2, 13, 1, 3, 9, 11, 14, 2, 6, 8, 0, 13, 7, 12, 5, 9, 6, 9, 9, 14, 5, 5, 0, 4, 9, 9, 8, 2, 9, 2, 5, 0, 2, 5, 5, 2, 5, 0, 13, 14, 2, 9, 9, 12, 5, 2, 10, 11, 1, 11, 5, 1, 6, 1, 10, 0, 14, 11, 5, 14, 0, 7, 5, 6, 14, 3, 9, 6, 8, 0, 6, 13, 11, 14, 5, 8, 5, 9, 5, 3, 5, 5, 2, 2, 13, 11, 5, 0, 8, 11, 4, 10, 12, 0, 9, 14, 14, 14, 0, 10, 8, 2, 10, 4, 7, 13, 0, 5, 12, 9, 3, 11, 5, 0, 2, 5, 5, 8, 12, 8, 13, 14, 5, 10, 8, 9, 0, 11, 3, 11, 5, 9, 3, 7, 13, 10, 2, 13, 2, 2, 5, 13, 2, 0, 13, 8, 0, 14, 0, 13, 13, 6, 9, 4, 0, 2, 3, 0, 0, 10, 0, 0, 2, 8, 7, 12, 2, 11, 0, 5, 0, 0, 10, 14, 0, 10, 6, 14, 9, 8, 2, 5, 5, 10, 2, 11, 13, 11, 9, 11, 14, 13, 10, 14, 12, 5, 2, 14, 6, 2, 2, 2, 5, 0, 2, 0, 5, 8, 14, 0, 6, 9, 13, 0, 5, 14, 10, 9, 5, 5, 8, 2, 9, 2, 5, 0, 0, 12, 2, 14, 0, 12, 14, 0, 3, 2, 6, 9, 5, 0, 9, 13, 3, 11, 8, 0, 9, 0, 3, 2, 5, 11, 9, 8, 2, 14, 2, 13, 5, 9, 7, 6, 12, 5, 9, 14, 5, 2, 7, 8, 12, 13, 14, 13, 7, 9, 2, 4, 10, 10, 6, 11, 2, 7, 7, 2, 0, 13, 2, 5, 7, 2, 12, 14, 2, 9, 12, 8, 0, 6, 13, 2, 0, 5, 12, 14, 3, 10, 1, 13, 13, 14, 5, 14, 2, 13, 12, 5, 6, 11, 2, 5, 3, 11, 2, 11, 5, 14, 2, 11, 2, 6, 2, 6, 8, 1, 14, 0, 5, 12, 8, 12, 10, 12, 5, 8, 14, 2, 14, 0, 10, 6, 5, 6, 6, 9, 5, 7, 10, 13, 6, 3, 0, 14, 6, 4, 9, 0, 5, 0, 5, 0, 0, 6, 3, 0, 11, 6, 8, 9, 13, 13, 2, 0, 7, 10, 8, 7, 6, 11, 14, 11, 7, 12, 7, 0, 9, 13, 11, 2, 6, 4, 2, 13, 6, 0, 5, 14, 14, 2, 10, 14, 6, 9, 12, 0, 6, 2, 10, 7, 4, 14, 2, 14, 0, 10, 10, 2, 3, 2, 0, 9, 12, 14, 5, 9, 13, 2, 5, 10, 9, 10, 6, 2, 13, 2, 10, 9, 14, 10, 6, 4, 9, 12, 12, 0, 5, 13, 14, 0, 0, 5, 5, 9, 0, 5, 9, 8, 2, 5, 2, 5, 13, 9, 7, 0, 14, 4, 9, 9, 6, 7, 5, 0, 0, 2, 0, 14, 5, 7, 9, 0, 5, 13, 5, 7, 9, 6, 10, 12, 13, 4, 13, 5, 6, 1, 8, 5, 2, 11, 2, 3, 5, 7, 5, 6, 5, 0, 14, 0, 0, 10, 14, 5, 0, 14, 12, 10, 6, 2, 10, 5, 14, 5, 5, 9, 5, 3, 5, 7, 11, 8, 2, 13, 2, 7, 0, 10, 9, 13, 9, 0, 14, 10, 5, 10, 2, 0, 9, 0, 13, 14, 2, 9, 13, 5, 0, 14, 0, 7, 5, 2, 8, 5, 13, 2, 12, 9, 1, 5, 6, 11, 0, 14, 9, 5, 5, 0, 2, 1, 13, 13, 5, 0, 5, 0, 13, 2, 6, 9, 7, 11, 0, 5, 2, 2, 0, 11, 9, 8, 14, 3, 5, 10, 2, 7, 5, 5, 0, 14, 3, 5, 0, 0, 6, 4, 12, 0, 6, 2, 13, 6, 9, 13, 2, 5, 0, 3, 3, 0, 2, 13, 3, 14, 1, 4, 12, 13, 14, 0, 3, 9, 0, 3, 2, 13, 3, 2, 7, 2, 0, 4, 5, 2, 0, 2, 6, 5, 0, 13, 2, 9, 6, 14, 5, ...

# %%
print np.bincount(z)
freq_class = argsort(bincount(z))[::-1][: 8]
print freq_class
# Out:
# [294 210 284 271 343 382 376 428 278 452 405 375 460 488 402]
# [13 12  9  7 10 14  5  6]

# %%
print len(theta)
indices = argsort(theta, axis = 1)
best = indices[:,-40:]
for k in freq_class:
    wordlist = [vocab[best[k][j]] for j in range(len(best[0]))]          
    print wordlist
# Out:
# 15
# [u'#cruztovictori', u'rubio', u'sick', u'heat', u'\u2b06\ufe0f', u'could', u'#tcot', u'oz', u'#berni', u'bia', u'#hillari', u'dead', u'great', u'state', u'lose', u'ht\u2026', u'#feelthebern', u'#gop', u'#secprimari', u'call', u'news', u'#makeamericagreatagain', u'stage', u'poll', u'endors', u'#cruz2016', u'break', u'take', u'#choosecruz', u'#tedcruz', u'#trump', u'amp', u'texa', u'trump', u'#alwaystrump', u'vote', u'ted', u'#trump2016', u'#cruzcrew', u'cruz']
# [u'fight\r\r#feelthebern\r#\u2026', u'#hillari', u'idea', u'today', u'right', u'unelect', u'amp', u'seriou', u'#hillaryclinton', u'parti', u'presid', u'want', u'post', u'trump', u'lead', u'candid', u'#alwaystrump', u'democrat', u'need', u'sander', u'republican', u'poll', u'gop', u'#pjnet', u'clinton', u'say', u'#berniesand', u'#trump2016', u'get', u'#imwithh', u'mt', u'vote', u'dont', u'cruz', u'#tedcruz', u'ted', u'hillari', u'#cruzcrew', u'berni', u'#feelthebern']
# [u'peopl', u'#supertuesday', u'mt', u'#union', u'hope', u'march', u'ht\u2026', u'issu', u'choic', u'say', u'evangelicals#alwaystrump#votetrumphttpstconv\u2026', u'#trump', u'worker', u'#hillari', u'#pjnet', u'#berni', u'#hillaryclinton', u'return', u'key', u'call', u'get', u'take', u'american', u'tith', u'back', u'#bernie2016', u'#cruzcrew', u'silentabout', u'best', u'campaign', u'#imwithh', u'tax', u'#secprimari', u'#tedcruz', u'vote', u'trump', u'#berniesand', u'#feelthebern', u'amp', u'#alwaystrump']
# [u'trending#hillaryclinton', u'show', u'thirdparti', u'#gope#wakeupamerica', u'#hillari', u'loser', u'dalla', u'fast', u'vote', u'tomorrow', u'brilliant', u'candidate#alwaystrump#votetrump2016#secprimaryhttpst\u2026', u'progress', u'#trumptrain', u'nychttpstcoxibfviodaa#wethepeopl', u'#berniesand', u'grayson', u'cheater', u'liars#gopsmartset', u'rep', u'work', u'antitrump', u'made', u'#pjnet', u'join', u'establish', u'perfectionnot', u'let', u'attack', u'ad', u'thank', u'mt', u'alan', u'#makeamericagreatagain', u'#feelthebern', u'endors', u'#hillaryclinton', u'#cruzcrew', u'#tedcruz', u'#imwithh']
# [u'#alwaystrump#onlytrumpdont', u'hillari', u'ahead', u'vote', u'#tedcruz', u'31', u'ditch', u'releas', u'#coprimari', u'stand', u'campaignon', u'conserv', u'huckabe', u'tuesday', u'super', u'#txprimari', u'#nevertrump', u'now#trump2016', u'unit', u'behind', u'#berniesand', u'revolutionstrongest', u'trump', u'dont', u'#choosecruz', u'social', u'mediath', u'peopl', u'#supertuesday', u'continu', u'tool', u'#cruzcrew', u'must', u'sander', u'fight', u'right', u'berni', u'#alwaystrump', u'#feelthebern', u'endors']
# [u'evangel', u'pro', u'hillari', u'trust', u'cannot', u'gentl', u'climat', u'5', u'watchchat', u'#trumptrain', u'est', u'decis', u'support', u'4', u'media', u'human', u'remind', u'futur', u'\u2014', u'#a\u2026', u'expect', u'#texa', u'pm', u'ted', u'get', u'win', u'vote', u'12', u'#tedcruz', u'cruz', u'va', u'stream', u'#alwaystrump', u'donald', u'univers', u'ralli', u'live', u'trump', u'radford', u'amp']
# [u'crass', u'trust', u'ga\U0001f3896', u'ok#drugtestrubio', u'conserv', u'va\U0001f38912', u'#yug', u'pm', u'#trump2016', u'great', u'ted', u'now\U0001f389donald', u'nation', u'hear', u'va\U0001f389#votetrumpva#secprimary#trump2016#trumptrain\U0001f682\U0001f1fa\U0001f1f8httpst\u2026', u'poll', u'support', u'steam', u'natl', u'today\U0001f389donald', u'earn', u'presid', u'#trumptrain', u'cruz', u'#rubio#cruz', u'uni', u'poll#alwaystrump#secprimaryhttpstcowfl8la2srn', u'\U0001f4a51st', u'radford', u'#makeamericagreatagain', u'cnn', u'america', u'ralli', u'vote', u'crush', u'49', u'#supertuesday', u'donald', u'#alwaystrump', u'trump']
# [u'#hillary2016', u'nashvil', u'mayor', u'#sheli', u'gotham', u'outta', u'play', u'#trump2016', u'york', u'poll', u'#p2', u'#alwayst\u2026', u'data', u'#hillaryclinton', u'#hilly', u'troubl', u'show', u'thank', u'#vote4grayson', u'via', u'berni', u'#supertuesday', u'#imwithh', u'megan', u'clinton', u'herebi', u'nomine', u'unit', u'state', u'presid', u'endors', u'could', u'#feelthebern', u'#trump2016httpstcofqr48cvibt', u'york#makeamericagreatagain', u'lose', u'trump', u'new', u'hillari', u'democrat']

# %% [markdown]
# # Part 2: Number of posts from each user partition

# %% [markdown]
# Load the Pickle file `../Data/users-partition.pickle`, you will get a dictionary which represents a partition over 452,743 Twitter users, `{user_id: partition_id}`. The users are partitioned into 7 groups. For example, if the dictionary is loaded into a variable named `partition`, the partition ID of the user `59458445` is `partition["59458445"]`. These users are partitioned into 7 groups. The partition ID is an integer between 0-6.
#
# Note that the user partition we provide doesn't cover all users appear in the input data.

# %% [markdown]
# (1) Load the pickle file.

# %% [markdown]
# # your code here
# import pickle
# file_Name = '../Data/users-partition.pickle'
# fileObject = open(file_Name,'r')
# b = pickle.load(fileObject)

# %% [markdown]
# (2) Count the number of posts from each user partition
#
# Count the number of posts from group 0, 1, ..., 6, plus the number of posts from users who are not in any partition. Assign users who are not in any partition to the group 7.
#
# Put the results of this step into a pair RDD `(group_id, count)` that is sorted by key.

# %% [markdown]
# # your code here
# default = 7
# counts_id = rdd2.map(lambda x: (b.get( x[0], default), 1))\
#                 .reduceByKey(lambda x,y:x+y).sortByKey()

# %% [markdown]
# (3) Print the post count using the `print_post_count` function we provided.
#
# It should print
#
# ```
# Group 0 posted 81 tweets
# Group 1 posted 199 tweets
# Group 2 posted 45 tweets
# Group 3 posted 313 tweets
# Group 4 posted 86 tweets
# Group 5 posted 221 tweets
# Group 6 posted 400 tweets
# Group 7 posted 798 tweets
# ```

# %%
def print_post_count(counts):
    for group_id, count in counts:
        print 'Group %d posted %d tweets' % (group_id, count)

# %% [markdown]
# # Part 3:  Tokens that are relatively popular in each user partition

# %% [markdown]
# In this step, we are going to find tokens that are relatively popular in each user partition.
#
# We define the number of mentions of a token $t$ in a specific user partition $k$ as the number of users from the user partition $k$ that ever mentioned the token $t$ in their tweets. Note that even if some users might mention a token $t$ multiple times or in multiple tweets, a user will contribute at most 1 to the counter of the token $t$.
#
# Please make sure that the number of mentions of a token is equal to the number of users who mentioned this token but NOT the number of tweets that mentioned this token.
#
# Let $N_t^k$ be the number of mentions of the token $t$ in the user partition $k$. Let $N_t^{all} = \sum_{i=0}^7 N_t^{i}$ be the number of total mentions of the token $t$.
#
# We define the relative popularity of a token $t$ in a user partition $k$ as the log ratio between $N_t^k$ and $N_t^{all}$, i.e.
#
# \begin{equation}
# p_t^k = \log \frac{C_t^k}{C_t^{all}}.
# \end{equation}
#
#
# You can compute the relative popularity by calling the function `get_rel_popularity`.

# %% [markdown]
# (0) Load the tweet tokenizer.

# %%
# %load happyfuntokenizing.py
#!/usr/bin/env python

"""
This code implements a basic, Twitter-aware tokenizer.

A tokenizer is a function that splits a string of text into words. In
Python terms, we map string and unicode objects into lists of unicode
objects.

There is not a single right way to do tokenizing. The best method
depends on the application.  This tokenizer is designed to be flexible
and this easy to adapt to new domains and tasks.  The basic logic is
this:

1. The tuple regex_strings defines a list of regular expression
   strings.

2. The regex_strings strings are put, in order, into a compiled
   regular expression object called word_re.

3. The tokenization is done by word_re.findall(s), where s is the
   user-supplied string, inside the tokenize() method of the class
   Tokenizer.

4. When instantiating Tokenizer objects, there is a single option:
   preserve_case.  By default, it is set to True. If it is set to
   False, then the tokenizer will downcase everything except for
   emoticons.

The __main__ method illustrates by tokenizing a few examples.

I've also included a Tokenizer method tokenize_random_tweet(). If the
twitter library is installed (http://code.google.com/p/python-twitter/)
and Twitter is cooperating, then it should tokenize a random
English-language tweet.


Julaiti Alafate:
  I modified the regex strings to extract URLs in tweets.
"""

__author__ = "Christopher Potts"
__copyright__ = "Copyright 2011, Christopher Potts"
__credits__ = []
__license__ = "Creative Commons Attribution-NonCommercial-ShareAlike 3.0 Unported License: http://creativecommons.org/licenses/by-nc-sa/3.0/"
__version__ = "1.0"
__maintainer__ = "Christopher Potts"
__email__ = "See the author's website"

######################################################################

import re
import htmlentitydefs

######################################################################
# The following strings are components in the regular expression
# that is used for tokenizing. It's important that phone_number
# appears first in the final regex (since it can contain whitespace).
# It also could matter that tags comes after emoticons, due to the
# possibility of having text like
#
#     <:| and some text >:)
#
# Most imporatantly, the final element should always be last, since it
# does a last ditch whitespace-based tokenization of whatever is left.

# This particular element is used in a couple ways, so we define it
# with a name:
emoticon_string = r"""
    (?:
      [<>]?
      [:;=8]                     # eyes
      [\-o\*\']?                 # optional nose
      [\)\]\(\[dDpP/\:\}\{@\|\\] # mouth      
      |
      [\)\]\(\[dDpP/\:\}\{@\|\\] # mouth
      [\-o\*\']?                 # optional nose
      [:;=8]                     # eyes
      [<>]?
    )"""

# The components of the tokenizer:
regex_strings = (
    # Phone numbers:
    r"""
    (?:
      (?:            # (international)
        \+?[01]
        [\-\s.]*
      )?            
      (?:            # (area code)
        [\(]?
        \d{3}
        [\-\s.\)]*
      )?    
      \d{3}          # exchange
      [\-\s.]*   
      \d{4}          # base
    )"""
    ,
    # URLs:
    r"""http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+"""
    ,
    # Emoticons:
    emoticon_string
    ,    
    # HTML tags:
     r"""<[^>]+>"""
    ,
    # Twitter username:
    r"""(?:@[\w_]+)"""
    ,
    # Twitter hashtags:
    r"""(?:\#+[\w_]+[\w\'_\-]*[\w_]+)"""
    ,
    # Remaining word types:
    r"""
    (?:[a-z][a-z'\-_]+[a-z])       # Words with apostrophes or dashes.
    |
    (?:[+\-]?\d+[,/.:-]\d+[+\-]?)  # Numbers, including fractions, decimals.
    |
    (?:[\w_]+)                     # Words without apostrophes or dashes.
    |
    (?:\.(?:\s*\.){1,})            # Ellipsis dots. 
    |
    (?:\S)                         # Everything else that isn't whitespace.
    """
    )

######################################################################
# This is the core tokenizing regex:
    
word_re = re.compile(r"""(%s)""" % "|".join(regex_strings), re.VERBOSE | re.I | re.UNICODE)

# The emoticon string gets its own regex so that we can preserve case for them as needed:
emoticon_re = re.compile(regex_strings[1], re.VERBOSE | re.I | re.UNICODE)

# These are for regularizing HTML entities to Unicode:
html_entity_digit_re = re.compile(r"&#\d+;")
html_entity_alpha_re = re.compile(r"&\w+;")
amp = "&amp;"

######################################################################

class Tokenizer:
    def __init__(self, preserve_case=False):
        self.preserve_case = preserve_case

    def tokenize(self, s):
        """
        Argument: s -- any string or unicode object
        Value: a tokenize list of strings; conatenating this list returns the original string if preserve_case=False
        """        
        # Try to ensure unicode:
        try:
            s = unicode(s)
        except UnicodeDecodeError:
            s = str(s).encode('string_escape')
            s = unicode(s)
        # Fix HTML character entitites:
        s = self.__html2unicode(s)
        # Tokenize:
        words = word_re.findall(s)
        # Possible alter the case, but avoid changing emoticons like :D into :d:
        if not self.preserve_case:            
            words = map((lambda x : x if emoticon_re.search(x) else x.lower()), words)
        return words

    def tokenize_random_tweet(self):
        """
        If the twitter library is installed and a twitter connection
        can be established, then tokenize a random tweet.
        """
        try:
            import twitter
        except ImportError:
            print "Apologies. The random tweet functionality requires the Python twitter library: http://code.google.com/p/python-twitter/"
        from random import shuffle
        api = twitter.Api()
        tweets = api.GetPublicTimeline()
        if tweets:
            for tweet in tweets:
                if tweet.user.lang == 'en':            
                    return self.tokenize(tweet.text)
        else:
            raise Exception("Apologies. I couldn't get Twitter to give me a public English-language tweet. Perhaps try again")

    def __html2unicode(self, s):
        """
        Internal metod that seeks to replace all the HTML entities in
        s with their corresponding unicode characters.
        """
        # First the digits:
        ents = set(html_entity_digit_re.findall(s))
        if len(ents) > 0:
            for ent in ents:
                entnum = ent[2:-1]
                try:
                    entnum = int(entnum)
                    s = s.replace(ent, unichr(entnum))	
                except:
                    pass
        # Now the alpha versions:
        ents = set(html_entity_alpha_re.findall(s))
        ents = filter((lambda x : x != amp), ents)
        for ent in ents:
            entname = ent[1:-1]
            try:            
                s = s.replace(ent, unichr(htmlentitydefs.name2codepoint[entname]))
            except:
                pass                    
            s = s.replace(amp, " and ")
        return s

# %% [markdown]
# from math import log
#
# tok = Tokenizer(preserve_case=False)
#
# def get_rel_popularity(c_k, c_all):
#     return log(1.0 * c_k / c_all) / log(2)
#
#
# def print_tokens(tokens, gid = None):
#     group_name = "overall"
#     if gid is not None:
#         group_name = "group %d" % gid
#     print '=' * 5 + ' ' + group_name + ' ' + '=' * 5
#     for n, t in tokens:
#         print "%s\t%.4f" % (t.encode('utf-8'), -n)
#     print

# %% [markdown]
# (1) Tokenize the tweets using the tokenizer we provided above named `tok`. Count the number of mentions for each tokens regardless of specific user group.
#
# Call `print_count` function to show how many different tokens we have.
#
# It should print
# ```
# Number of elements: 8949
# ```

# %% [markdown]
# # your code here
# rdd_token2 = rdd2.mapValues(lambda x: tok.tokenize(x.encode('utf-8')))\
#                 .reduceByKey(lambda a, b: a+b).mapValues(lambda x: list(set(x)))\
#                 .map(lambda (c,v): (b.get( c, default),v))
# rdd_freq= rdd_token2.flatMap(lambda (c, v) : v).map(lambda x: (x,1)).reduceByKey(lambda a,b:a+b)
# print_count(rdd_freq)
# #rdd_token2.take(2)
# rdd_token2.take(2)

# %% [markdown]
# (2) Tokens that are mentioned by too few users are usually not very interesting. So we want to only keep tokens that are mentioned by at least 100 users. Please filter out tokens that don't meet this requirement.
#
# Call `print_count` function to show how many different tokens we have after the filtering.
#
# Call `print_tokens` function to show top 20 most frequent tokens.
#
# It should print
# ```
# Number of elements: 44
# ===== overall =====
# :	1388.0000
# rt	1237.0000
# .	826.0000
# …	673.0000
# the	623.0000
# trump	582.0000
# to	499.0000
# ,	489.0000
# a	404.0000
# is	376.0000
# in	297.0000
# of	292.0000
# and	288.0000
# for	281.0000
# !	269.0000
# ?	210.0000
# on	195.0000
# i	192.0000
# you	191.0000
# this	190.0000
# ```

# %% [markdown]
# # your code here
# rdd_filt = rdd_freq.filter(lambda (c,v): v >=100)
# freq_sort = rdd_filt.sortBy(lambda x: (-x[1], x[0])).map(lambda (c,v): (-v, c))
# print_count(rdd_filt)
# print_tokens(freq_sort.take(20))

# %% [markdown]
# (3) For all tokens that are mentioned by at least 100 users, compute their relative popularity in each user group. Then print the top 10 tokens with highest relative popularity in each user group. In case two tokens have same relative popularity, break the tie by printing the alphabetically smaller one.
#
# **Hint:** Let the relative popularity of a token $t$ be $p$. The order of the items will be satisfied by sorting them using (-p, t) as the key.
#
# It should print
# ```
# ===== group 0 =====
# ...	-3.5648
# at	-3.5983
# hillary	-4.0875
# i	-4.1255
# bernie	-4.1699
# not	-4.2479
# https	-4.2695
# he	-4.2801
# in	-4.3074
# are	-4.3646
#
# ===== group 1 =====
# #demdebate	-2.4391
# -	-2.6202
# &	-2.7472
# amp	-2.7472
# clinton	-2.7570
# ;	-2.7980
# sanders	-2.8838
# ?	-2.9069
# in	-2.9664
# if	-3.0138
#
# ===== group 2 =====
# are	-4.6865
# and	-4.7105
# bernie	-4.7549
# at	-4.7682
# sanders	-4.9542
# that	-5.0224
# in	-5.0444
# donald	-5.0618
# a	-5.0732
# #demdebate	-5.1396
#
# ===== group 3 =====
# #demdebate	-1.3847
# bernie	-1.8480
# sanders	-2.1887
# of	-2.2356
# that	-2.3785
# the	-2.4376
# …	-2.4403
# clinton	-2.4467
# hillary	-2.4594
# be	-2.5465
#
# ===== group 4 =====
# hillary	-3.7395
# sanders	-3.9542
# of	-4.0199
# clinton	-4.0790
# at	-4.1832
# in	-4.2143
# a	-4.2659
# on	-4.2854
# .	-4.3681
# the	-4.4251
#
# ===== group 5 =====
# cruz	-2.3861
# he	-2.6280
# are	-2.7796
# will	-2.7829
# the	-2.8568
# is	-2.8822
# for	-2.9250
# that	-2.9349
# of	-2.9804
# this	-2.9849
#
# ===== group 6 =====
# @realdonaldtrump	-1.1520
# cruz	-1.4532
# https	-1.5222
# !	-1.5479
# not	-1.8904
# …	-1.9269
# will	-2.0124
# it	-2.0345
# this	-2.1104
# to	-2.1685
#
# ===== group 7 =====
# donald	-0.6422
# ...	-0.7922
# sanders	-1.0282
# trump	-1.1296
# bernie	-1.2106
# -	-1.2253
# you	-1.2376
# clinton	-1.2511
# if	-1.2880
# i	-1.2996
# ```

# %% [markdown]
# # your code here
# rdd_group= rdd_token2.flatMapValues(lambda v : v).map(lambda (c,v): (v,c))\
#             .map(lambda x: (x,1)).reduceByKey(lambda a,b:a+b)
# #rdd_group.take(5)
# def getKey(item):
#     return item[1]
# #, key=getKey, reverse=True
#
# rdd_joined = rdd_filt.join(rdd_group.map(lambda ((t, w), u): (t, (w,u))))\
#               .map(lambda (t, (v, (w, u))): ((t, w), (u, v)))
# rdd_grouped = rdd_joined.mapValues(lambda x: log(1.0 * x[0] / x[1]) / log(2))\
#                    .map(lambda ((t, w), u): (w, (-u,t))).groupByKey()\
#                     .mapValues(lambda x: sorted(x))
#         #.mapValues(lambda (c,v): (v, -c))
# #rdd_grouped.take(8)
# for n in range(8):
#     print_tokens(rdd_grouped.collectAsMap()[n][0:10],n)

# %% [markdown]
# (4) (optional, not for grading) The users partition is generated by a machine learning algorithm that tries to group the users by their political preferences. Three of the user groups are showing supports to Bernie Sanders, Ted Cruz, and Donald Trump.
#
# If your program looks okay on the local test data, you can try it on the larger input by submitting your program to the homework server. Observe the output of your program to larger input files, can you guess the partition IDs of the three groups mentioned above based on your output?

# %% [markdown]
# # Change the values of the following three items to your guesses
#
# users_support = [
#     (-1, "Bernie Sanders"),
#     (-1, "Ted Cruz"),
#     (-1, "Donald Trump")
# ]
#
# for gid, candidate in users_support:
#     print "Users from group %d are most likely to support %s." % (gid, candidate)
